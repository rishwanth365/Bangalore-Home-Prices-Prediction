# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
pd.set_option('display.max_rows', None)
df1 = pd.read_csv("bengaluru_house_prices.csv")
df1.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df1.shape
# Out:
# (13320, 9)

# %%
df1.area_type.value_counts()
# Out:
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64

# %%
df1.availability.unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
df1["size"].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df1.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df2 = df1.drop(['area_type', 'availability','balcony','society'],axis=1)
df2.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
df2.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df3 = df2.dropna()
df3.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
df3.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
df3.shape
# Out:
# (13246, 5)

# %%
df3["size"].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df3 = df3.copy()
df3.loc[:,"bhk"] = df3["size"].apply(lambda x: int(x.split(' ')[0]))
df3.bhk.unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18], dtype=int64)

# %%
df3.head()
# Out:
#                    location       size total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2               Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                  Kothanur      2 BHK       1200   2.0   51.00    2

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df3[~df3["total_sqft"].apply(is_float)].head(10)
# Out:
#                location       size      total_sqft  bath    price  bhk
# 30            Yelahanka      4 BHK     2100 - 2850   4.0  186.000    4
# 122              Hebbal      4 BHK     3067 - 8156   4.0  477.000    4
# 137  8th Phase JP Nagar      2 BHK     1042 - 1105   2.0   54.005    2
# 165            Sarjapur      2 BHK     1145 - 1340   2.0   43.490    2
# 188            KR Puram      2 BHK     1015 - 1540   2.0   56.800    2
# 410             Kengeri      1 BHK  34.46Sq. Meter   1.0   18.500    1
# 549         Hennur Road      2 BHK     1195 - 1440   2.0   63.770    2
# 648             Arekere  9 Bedroom       4125Perch   9.0  265.000    9
# 661           Yelahanka      2 BHK     1120 - 1145   2.0   48.130    2
# 672        Bettahalsoor  4 Bedroom     3090 - 5002   4.0  445.000    4

# %%
def convert_float(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
df3.loc[:,'total_sqft'] = df3['total_sqft'].apply(convert_float)

# %%
df3.isnull().sum()
# Out:
# location       0
# size           0
# total_sqft    46
# bath           0
# price          0
# bhk            0
# dtype: int64

# %%
df4 = df3.dropna()
df4.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# bhk           0
# dtype: int64

# %%
df4.loc[30]
# Out:
# location      Yelahanka
# size              4 BHK
# total_sqft       2475.0
# bath                4.0
# price             186.0
# bhk                   4
# Name: 30, dtype: object

# %%
df4.head()
# Out:
#                    location       size total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK     1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom     2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK     1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK     1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK     1200.0   2.0   51.00    2

# %%
df4[~df4["total_sqft"].apply(is_float)]
# Out:
# Empty DataFrame
# Columns: [location, size, total_sqft, bath, price, bhk]
# Index: []

# %%
df5 = df4.copy()
df5.loc[:,'price_per_sqft'] = df5['price']*100000/df5['total_sqft']
df5.head()
# Out:
#                    location       size total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK     1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom     2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK     1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK     1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK     1200.0   2.0   51.00    2
#
#   price_per_sqft
# 0    3699.810606
# 1    4615.384615
# 2    4305.555556
# 3    6245.890861
# 4         4250.0

# %%
df5['price_per_sqft'].describe()
# Out:
# count     13200.0
# unique     7537.0
# top        5000.0
# freq        147.0
# Name: price_per_sqft, dtype: float64

# %%
df5.loc[:, 'location'] = df5['location'].apply(lambda x: x.strip())

# %%
location_stats = df5['location'].value_counts()
location_stats
# Out:
# location
# Whitefield                                            533
# Sarjapur  Road                                        392
# Electronic City                                       304
# Kanakpura Road                                        264
# Thanisandra                                           235
# Yelahanka                                             210
# Uttarahalli                                           186
# Hebbal                                                176
# Marathahalli                                          175
# Raja Rajeshwari Nagar                                 171
# Bannerghatta Road                                     151
# Hennur Road                                           150
# 7th Phase JP Nagar                                    148
# Haralur Road                                          141
# Electronic City Phase II                              131
# Rajaji Nagar                                          106
# Chandapura                                             98
# Bellandur                                              96
# Hoodi                                                  88
# KR Puram                                               88
# Electronics City Phase 1                               87
# Yeshwanthpur                                           85
# Begur Road                                             84
# Sarjapur                                               80
# Kasavanhalli                                           79
# Harlur                                                 79
# Hormavu                                                74
# Banashankari                                           74
# Kengeri                                                72
# Ramamurthy Nagar                                       72
# Koramangala                                            72
# Varthur                                                70
# Old Madras Road                                        70
# Hosa Road                                              69
# Jakkur                                                 68
# JP Nagar                                               66
# Kothanur                                               66
# Kaggadasapura                                          64
# Nagarbhavi                                             63
# Akshaya Nagar                                          62
# Thigalarapalya                                         62
# TC Palaya                                              60
# Rachenahalli                                           58
# Malleshwaram                                           57
# 8th Phase JP Nagar                                     57
# Budigere                                               54
# HSR Layout                                             53
# Jalahalli                                              52
# Hennur                                                 52
# Panathur                                               51
# Bisuvanahalli                                          51
# Jigani                                                 51
# Hulimavu                                               51
# Ramagondanahalli                                       50
# Hegde Nagar                                            49
# Bhoganhalli                                            49
# Gottigere                                              48
# Mysore Road                                            48
# Kundalahalli                                           47
# Brookefield                                            47
# Hosur Road                                             46
# Balagere                                               45
# Indira Nagar                                           44
# Vidyaranyapura                                         43
# Subramanyapura                                         43
# Vittasandra                                            43
# CV Raman Nagar                                         43
# 9th Phase JP Nagar                                     43
# Kadugodi                                               42
# Kanakapura                                             42
# Vijayanagar                                            42
# Attibele                                               42
# Horamavu Agara                                         42
# Talaghattapura                                         40
# Devanahalli                                            40
# Yelahanka New Town                                     40
# Kengeri Satellite Town                                 40
# 5th Phase JP Nagar                                     39
# Green Glen Layout                                      39
# Sahakara Nagar                                         39
# Channasandra                                           38
# Kudlu Gate                                             38
# Bommasandra                                            37
# Lakshminarayana Pura                                   36
# Hosakerehalli                                          36
# Anekal                                                 36
# R.T. Nagar                                             36
# Frazer Town                                            35
# Hebbal Kempapura                                       34
# Bommanahalli                                           34
# Kalena Agrahara                                        33
# Tumkur Road                                            33
# Old Airport Road                                       33
# Basavangudi                                            32
# Ambedkar Nagar                                         31
# Mahadevpura                                            31
# Doddathoguru                                           30
# Chikkalasandra                                         30
# Ananth Nagar                                           30
# Kumaraswami Layout                                     30
# Dodda Nekkundi                                         29
# Kudlu                                                  29
# Kammasandra                                            29
# BTM 2nd Stage                                          29
# Padmanabhanagar                                        28
# Somasundara Palya                                      28
# Horamavu Banaswadi                                     28
# Banashankari Stage III                                 27
# Singasandra                                            27
# Kodichikkanahalli                                      27
# Ambalipura                                             27
# Anandapura                                             27
# Choodasandra                                           26
# Kothannur                                              26
# Margondanahalli                                        26
# Bommasandra Industrial Area                            26
# Gubbalala                                              26
# Babusapalaya                                           25
# Kogilu                                                 25
# Magadi Road                                            25
# Seegehalli                                             25
# Iblur Village                                          25
# Munnekollal                                            24
# Battarahalli                                           24
# 1st Phase JP Nagar                                     24
# Abbigere                                               24
# Amruthahalli                                           24
# Ardendale                                              24
# 2nd Stage Nagarbhavi                                   24
# Kambipura                                              24
# Lingadheeranahalli                                     23
# 6th Phase JP Nagar                                     23
# EPIP Zone                                              23
# Thubarahalli                                           22
# Kathriguppe                                            22
# Kaval Byrasandra                                       22
# Rayasandra                                             22
# Domlur                                                 22
# Sonnenahalli                                           22
# Gunjur                                                 22
# Hoskote                                                21
# Ulsoor                                                 21
# Basaveshwara Nagar                                     21
# Poorna Pragna Layout                                   20
# HBR Layout                                             20
# Binny Pete                                             20
# Sanjay nagar                                           20
# Yelachenahalli                                         20
# OMBR Layout                                            19
# Kalyan nagar                                           19
# HRBR Layout                                            19
# Pai Layout                                             19
# Kaggalipura                                            19
# Kannamangala                                           18
# Doddanakundi Industrial Area 2                          6
# Rajiv Gandhi Nagar                                      6
# Chelekare                                               6
# Varanasi                                                6
# Srinivasa Nagar                                         6
# Nayandanahalli                                          6
# Devasthanagalu                                          6
# Shantiniketan Layout                                    6
# Amblipura                                               6
# Nagawara Junction                                       6
# Byrathi Village                                         6
# ITI Layout                                              6
# Doddakannelli                                           6
# Bagalakunte                                             6
# Lavelle Road                                            5
# Maithri Layout                                          5
# Stage-4 Bommanahalli                                    5
# Nagashetty Halli                                        5
# Kallumantapa                                            5
# Virat Nagar                                             5
# VGP Layout                                              5
# Maruthi Nagar                                           5
# Bagalur                                                 5
# Hiremath Layout                                         5
# Raghuvanahalli                                          5
# KR Garden                                               5
# Kadabagere                                              5
# Nagaraja Garden                                         5
# Munivenkatppa Layout                                    5
# 9th Block Jayanagar                                     5
# Bellari Road                                            5
# Coconut Grove Layout                                    5
# RMV Extension                                           5
# 3rd Block Banashankari                                  5
# 6th block Koramangala                                   5
# Byagadadhenahalli                                       5
# Doddabanahalli                                          5
# Hosahalli Extension                                     5
# Attur Layout                                            5
# Sunkadakatte                                            5
# Jakkuru Layout                                          5
# Nagondanahalli                                          5
# Srirampuram                                             5
# Amruthnagar                                             5
# Off Sarjapur Road,                                      5
# Govindpura                                              5
# Devi Nagar                                              5
# Akshya Nagar                                            5
# Kurubarahalli                                           5
# A Narayanapura                                          5
# 1st Stage Indira Nagar                                  5
# Cottonpet                                               5
# Chikkadunnasandra                                       5
# Jakkasandra Extension                                   5
# Pattanagere                                             5
# Vishwapriya Nagar                                       5
# Doopanahalli                                            5
# Mallathahalli                                           5
# Vasantha Vallabha Nagar                                 5
# Ramanjaneyanagar                                        5
# Kadugondanahalli                                        5
# New Gurappana Palya                                     5
# Avalahalli                                              5
# 7th Block Jayanagar                                     5
# Belathur                                                5
# Dodda Banaswadi                                         5
# Shanthala Nagar                                         5
# HMT Layout                                              5
# Silk Board                                              5
# Kada Agrahara                                           5
# Upkar Layout                                            4
# 4th Phase JP Nagar                                      4
# Raja Rajeshwari Nagar 5th Stage                         4
# 2nd Block Jayanagar                                     4
# Alfa Garden Layout                                      4
# Chikkathoguru                                           4
# Lakshmi Layout                                          4
# Divya Unnathi Layout                                    4
# Basavanagara                                            4
# T Dasarahalli                                           4
# Judicial Layout, Kanakapura Road,                       4
# Basavanna Nagar                                         4
# Udaya Nagar                                             4
# Thanisandra main road                                   4
# Tavarekere                                              4
# Manjunath Nagar                                         4
# Konanakunte Cross                                       4
# Doddagubbi                                              4
# Chikkasandra                                            4
# Jnanabharathi Layout                                    4
# Kodathi                                                 4
# RWF West Colony                                         4
# Vaishnavi Layout                                        4
# Mysore Highway                                          4
# Kuvempu Nagar                                           4
# 4th Block Jayanagar                                     4
# Carmelaram                                              4
# Herohalli                                               4
# Laxmi Sagar Layout                                      4
# Chinnapanahalli                                         4
# BEL Road                                                4
# Mylasandra                                              4
# tc.palya                                                4
# Kirloskar Layout                                        4
# MCECHS  layout                                          4
# NS Palya                                                4
# Poornapragna Housing Society Layout                     4
# 8th Block Jayanagar                                     4
# Bikasipura                                              4
# Ngef Layout                                             4
# Tala Cauvery Layout                                     4
# Dooravani Nagar                                         4
# BSM Extension                                           4
# JCR Layout                                              4
# Silver Springs Layout                                   4
# Varsova Layout                                          4
# Chennappa Layout                                        4
# Immadihalli                                             4
# Moodalapalya                                            4
# Kammagondahalli                                         4
# Puttanahalli                                            4
# Hanumanth Nagar                                         4
# Bagalur Main Road                                       4
# Tata Nagar                                              4
# OLd Gurappanapalya                                      4
# Lake City                                               4
# Geddalahalli                                            4
# Udayapur Village                                        4
# Vinayaka Nagar                                          4
# Kumarapalli                                             4
# Suddaguntepalya                                         4
# Harsha Layout                                           4
# Palace Guttahalli                                       4
# BCC Layout                                              4
# Sai Gardens                                             4
# Shankarapuram                                           4
# Ramamurthy Nagar Extension                              4
# AMS Layout                                              4
# Sector 6 HSR Layout                                     4
# Kamala Nagar                                            4
# Brooke Bond First Cross                                 4
# Glass Factory Layout                                    4
# Nyanappana Halli                                        4
# Pragathi Nagar                                          4
# Lavakusha Nagar                                         4
# Bhuvaneswari Nagar                                      3
# Sri Balaji Krupa Layout                                 3
# Rajarajeshwari nagar                                    3
# Alur                                                    3
# Jinkethimmanahalli                                      3
# Adityanagar                                             3
# Shettigere                                              3
# Lakshmipura                                             3
# Kodipalya                                               3
# Baba Nagar                                              3
# Atmananda Colony                                        3
# Vimanapura                                              3
# Kengeri Hobli                                           3
# Bidadi                                                  3
# Bhagyalakshmi Avenue                                    3
# Bethel Nagar                                            3
# Venugopal Reddy Layout                                  3
# Kithaganur                                              3
# Tunganagara                                             3
# Dollars Layout                                          3
# Sampangi Rama Nagar                                     3
# Jayanti Nagar                                           3
# Lottegolla Halli                                        3
# 5th Block Jayanagar                                     3
# Manorayana Palya                                        3
# SMV layout                                              3
# Yeshwanthpur Industrial Suburb                          3
# Nandini Layout                                          3
# B Channasandra                                          3
# Govindapura                                             3
# Tasker Town                                             3
# Kothnur Narayanapura                                    3
# Arehalli                                                3
# Sadaramangala                                           3
# Hosapalya                                               3
# D Group Employees Layout                                3
# Ferrar Nagar                                            3
# Mangammanapalya                                         3
# Sanjeevini Nagar                                        3
# 3rd Phase JP Nagar                                      3
# Hagadur                                                 3
# Himagiri Meadows                                        3
# Thanisandra Main Road,                                  3
# Gowdanapalya                                            3
# Dinnur                                                  3
# Singanayakanahalli                                      3
# Kaveri Nagar                                            3
# J C Nagar                                               3
# Seshadripuram                                           3
# Langford Town                                           3
# Esther Enclave Layout                                   3
# Ilyas Nagar                                             3
# Gkvk Layout                                             3
# Sarvabhouma Nagar                                       3
# Ramesh Nagar                                            3
# Ashwini layout                                          3
# Prashanth Nagar                                         3
# Chikka Banaswadi                                        3
# RMV                                                     3
# Kavika Layout                                           3
# Telecom Layout                                          3
# Vadarpalya                                              3
# RPC layout                                              3
# Singena Agrahara                                        3
# 1st Block HBR Layout                                    3
# Srinagar                                                3
# Basava Nagar                                            3
# Nanjappa Layout                                         3
# Jayamahal                                               3
# 2nd Stage Arekere Mico Layout                           3
# 3rd Block Jayanagar                                     3
# T.C PALYA                                               3
# Canara Bank Layout                                      3
# Daadys Gaarden Layout                                   3
# BHEL Layout                                             3
# Virupakshapura                                          3
# Rajarajeshwari Nagara                                   3
# Tirumanahalli                                           3
# Surabhi Layout                                          3
# Narayana Nagar 1st Block                                3
# KSRTC Layout                                            3
# Vinayak Nagar                                           3
# Crimson Layout                                          3
# Hanumantha Nagar                                        3
# Devara Jeevanahalli                                     3
# Agrahara Dasarahalli                                    3
# Pampa Extension                                         3
# Ankappa Layout                                          3
# Makali                                                  3
# Domlur Layout                                           3
# Thippasandra                                            3
# Sanne Amanikere                                         3
# Gokula Extension                                        3
# Brindavan Nagar                                         3
# Devanahalli Int. Airport                                3
# Palanahalli                                             3
# Kashi Nagar                                             3
# Sathya Layout                                           3
# Gulimangala                                             3
# Nobo Nagar                                              3
# Ayappa Nagar                                            3
# 5th Stage BEML Layout                                   3
# P&T Layout                                              3
# Ullal Uppanagar                                         3
# Veerannapalya                                           3
# Marasandra                                              3
# Mathikere Extension                                     3
# Anantapura                                              3
# Coffee Board Layout                                     3
# Raghavendra Nagar                                       3
# Belatur                                                 3
# Weavers Colony                                          3
# Kamakya Layout                                          3
# Kachanayakanahalli                                      3
# Anjappa Layout                                          3
# Thurahalli                                              3
# Harappanahalli                                          3
# Hegganahalli                                            3
# KR Layout                                               3
# Gattahalli                                              3
# BTM 4th Stage                                           3
# VHBCS Layout                                            3
# Kenchenhalli                                            3
# Krishna Reddy Layout                                    3
# Venkatadri Layout                                       3
# Kumbena Agrahara                                        3
# Ullal Road                                              3
# Konena Agrahara                                         3
# Jnana Ganga Nagar                                       3
# Dasappa Layout                                          3
# Vittal Nagar                                            3
# Govindaraja Nagar Ward                                  2
# Rajankunte                                              2
# Postal Colony                                           2
# Bhoopsandra                                             2
# Arishinakunte                                           2
# Infantry Road                                           2
# Anwar Layout                                            2
# Annaiah Reddy Layout                                    2
# MLA Layout                                              2
# Amam Enclave Layout                                     2
# Koramangala Industrial Layout                           2
# Gattigere                                               2
# Kyalasanahalli                                          2
# Versova Layout                                          2
# Marenahalli                                             2
# Nanjappa Garden                                         2
# Lakkasandra                                             2
# Akshayanagara West                                      2
# Anand nagar                                             2
# Celebrity Paradise Layout                               2
# Hadosiddapura                                           2
# JP Nagar 8th Phase,                                     2
# Lal Bahadur Shastri Nagar                               2
# Ashok Nagar                                             2
# Gnana Bharathi                                          2
# Anugrah Layout                                          2
# RR Layout                                               2
# Annapurneshwari Nagar                                   2
# Vasanthpura                                             2
# Guddadahalli                                            2
# Kothnoor Dinne                                          2
# Dena Bank Colony                                        2
# Sadanand Nagar                                          2
# RMV Extension Stage 2                                   2
# Veer Sandra                                             2
# Gandhi Bazar                                            2
# 2nd Block Koramangala                                   2
# Chamundi Nagar                                          2
# Near International Airport                              2
# Raghavendra Layout                                      2
# Naidu Layout                                            2
# Anjana Nagar                                            2
# Janatha Colony                                          2
# Guni Agrahara                                           2
# Rajanna Layout                                          1
# Subramanyanagar                                         1
# Lakshmipura Vidyaanyapura                               1
# Malur Hosur Road                                        1
# Abshot Layout                                           1
# Name: count, dtype: int64

# %%
len(location_stats[location_stats>10])
# Out:
# 240

# %%
len(location_stats)
# Out:
# 1287

# %%
location_stats.values.sum()
# Out:
# 13200

# %%
len(location_stats[location_stats<=10])
# Out:
# 1047

# %%
df5 = df5.copy()
df5.loc[:,'location'] = df5['location'].apply(lambda x: 'other' if x in location_stats[location_stats<=10] else x)
df5.head(10)
# Out:
#                    location       size total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK     1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom     2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK     1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK     1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK     1200.0   2.0   51.00    2
# 5                Whitefield      2 BHK     1170.0   2.0   38.00    2
# 6          Old Airport Road      4 BHK     2732.0   4.0  204.00    4
# 7              Rajaji Nagar      4 BHK     3300.0   4.0  600.00    4
# 8              Marathahalli      3 BHK     1310.0   3.0   63.25    3
# 9                     other  6 Bedroom     1020.0   6.0  370.00    6
#
#   price_per_sqft
# 0    3699.810606
# 1    4615.384615
# 2    4305.555556
# 3    6245.890861
# 4         4250.0
# 5    3247.863248
# 6    7467.057101
# 7   18181.818182
# 8    4828.244275
# 9   36274.509804

# %%
df5['location'].value_counts()
# Out:
# location
# other                          2872
# Whitefield                      533
# Sarjapur  Road                  392
# Electronic City                 304
# Kanakpura Road                  264
# Thanisandra                     235
# Yelahanka                       210
# Uttarahalli                     186
# Hebbal                          176
# Marathahalli                    175
# Raja Rajeshwari Nagar           171
# Bannerghatta Road               151
# Hennur Road                     150
# 7th Phase JP Nagar              148
# Haralur Road                    141
# Electronic City Phase II        131
# Rajaji Nagar                    106
# Chandapura                       98
# Bellandur                        96
# Hoodi                            88
# KR Puram                         88
# Electronics City Phase 1         87
# Yeshwanthpur                     85
# Begur Road                       84
# Sarjapur                         80
# Kasavanhalli                     79
# Harlur                           79
# Hormavu                          74
# Banashankari                     74
# Kengeri                          72
# Ramamurthy Nagar                 72
# Koramangala                      72
# Varthur                          70
# Old Madras Road                  70
# Hosa Road                        69
# Jakkur                           68
# JP Nagar                         66
# Kothanur                         66
# Kaggadasapura                    64
# Nagarbhavi                       63
# Thigalarapalya                   62
# Akshaya Nagar                    62
# TC Palaya                        60
# Rachenahalli                     58
# Malleshwaram                     57
# 8th Phase JP Nagar               57
# Budigere                         54
# HSR Layout                       53
# Jalahalli                        52
# Hennur                           52
# Panathur                         51
# Hulimavu                         51
# Bisuvanahalli                    51
# Jigani                           51
# Ramagondanahalli                 50
# Hegde Nagar                      49
# Bhoganhalli                      49
# Gottigere                        48
# Mysore Road                      48
# Brookefield                      47
# Kundalahalli                     47
# Hosur Road                       46
# Balagere                         45
# Indira Nagar                     44
# CV Raman Nagar                   43
# Vittasandra                      43
# Vidyaranyapura                   43
# 9th Phase JP Nagar               43
# Subramanyapura                   43
# Vijayanagar                      42
# Kadugodi                         42
# Kanakapura                       42
# Horamavu Agara                   42
# Attibele                         42
# Kengeri Satellite Town           40
# Devanahalli                      40
# Talaghattapura                   40
# Yelahanka New Town               40
# 5th Phase JP Nagar               39
# Green Glen Layout                39
# Sahakara Nagar                   39
# Channasandra                     38
# Kudlu Gate                       38
# Bommasandra                      37
# Anekal                           36
# Hosakerehalli                    36
# Lakshminarayana Pura             36
# R.T. Nagar                       36
# Frazer Town                      35
# Bommanahalli                     34
# Hebbal Kempapura                 34
# Old Airport Road                 33
# Tumkur Road                      33
# Kalena Agrahara                  33
# Basavangudi                      32
# Ambedkar Nagar                   31
# Mahadevpura                      31
# Chikkalasandra                   30
# Kumaraswami Layout               30
# Doddathoguru                     30
# Ananth Nagar                     30
# Dodda Nekkundi                   29
# Kudlu                            29
# Kammasandra                      29
# BTM 2nd Stage                    29
# Horamavu Banaswadi               28
# Somasundara Palya                28
# Padmanabhanagar                  28
# Banashankari Stage III           27
# Singasandra                      27
# Ambalipura                       27
# Anandapura                       27
# Kodichikkanahalli                27
# Margondanahalli                  26
# Kothannur                        26
# Gubbalala                        26
# Bommasandra Industrial Area      26
# Choodasandra                     26
# Magadi Road                      25
# Babusapalaya                     25
# Kogilu                           25
# Iblur Village                    25
# Seegehalli                       25
# Kambipura                        24
# Amruthahalli                     24
# Ardendale                        24
# Abbigere                         24
# Munnekollal                      24
# 2nd Stage Nagarbhavi             24
# 1st Phase JP Nagar               24
# Battarahalli                     24
# EPIP Zone                        23
# 6th Phase JP Nagar               23
# Lingadheeranahalli               23
# Rayasandra                       22
# Kaval Byrasandra                 22
# Domlur                           22
# Kathriguppe                      22
# Sonnenahalli                     22
# Thubarahalli                     22
# Gunjur                           22
# Basaveshwara Nagar               21
# Hoskote                          21
# Ulsoor                           21
# HBR Layout                       20
# Sanjay nagar                     20
# Yelachenahalli                   20
# Binny Pete                       20
# Poorna Pragna Layout             20
# Pai Layout                       19
# Kalyan nagar                     19
# Kaggalipura                      19
# HRBR Layout                      19
# OMBR Layout                      19
# Garudachar Palya                 18
# Kannamangala                     18
# Billekahalli                     18
# Kaikondrahalli                   17
# Malleshpalya                     17
# Devarachikkanahalli              17
# Sarjapura - Attibele Road        17
# Dasarahalli                      17
# Kammanahalli                     17
# Nagavara                         17
# Chikka Tirupathi                 17
# Banaswadi                        17
# Bannerghatta                     17
# Anjanapura                       16
# Mallasandra                      16
# Sector 2 HSR Layout              16
# Begur                            16
# BTM Layout                       16
# Banashankari Stage VI            16
# Kasturi Nagar                    16
# Parappana Agrahara               16
# Banashankari Stage II            16
# Kereguddadahalli                 16
# Dasanapura                       16
# Cooke Town                       16
# Kenchenahalli                    16
# Arekere                          16
# Varthur Road                     15
# Benson Town                      15
# Kodihalli                        15
# Nagavarapalya                    15
# Judicial Layout                  15
# Sarakki Nagar                    14
# NGR Layout                       14
# NRI Layout                       14
# Sultan Palaya                    14
# 1st Block Jayanagar              14
# Murugeshpalya                    14
# Jalahalli East                   14
# Giri Nagar                       14
# Doddakallasandra                 14
# Chamrajpet                       14
# Neeladri Nagar                   13
# Prithvi Layout                   13
# Shivaji Nagar                    13
# Gollarapalya Hosahalli           13
# Kadubeesanahalli                 13
# Konanakunte                      13
# Yelenahalli                      13
# Vishveshwarya Layout             13
# Sector 7 HSR Layout              13
# Mahalakshmi Layout               13
# Rajiv Nagar                      13
# Shampura                         13
# Chikkabanavar                    13
# Kodigehaali                      13
# Dommasandra                      13
# Cunningham Road                  13
# ISRO Layout                      13
# BEML Layout                      13
# Nagasandra                       12
# Karuna Nagar                     12
# Badavala Nagar                   12
# Sompura                          12
# AECS Layout                      12
# Bharathi Nagar                   12
# Laggere                          12
# ITPL                             12
# Mico Layout                      12
# Banashankari Stage V             12
# Cox Town                         12
# GM Palaya                        12
# Vasanthapura                     12
# 5th Block Hbr Layout             12
# Vishwapriya Layout               12
# Banjara Layout                   11
# Pattandur Agrahara               11
# LB Shastri Nagar                 11
# Nehru Nagar                      11
# 2nd Phase Judicial Layout        11
# Narayanapura                     11
# Bommenahalli                     11
# Doddaballapur                    11
# Tindlu                           11
# Marsur                           11
# HAL 2nd Stage                    11
# Kodigehalli                      11
# Name: count, dtype: int64

# %%
df5[df5['total_sqft']/df5['bhk']<300]
# Out:
#                        location        size total_sqft  bath   price  bhk  \
# 9                         other   6 Bedroom     1020.0   6.0  370.00    6
# 45                   HSR Layout   8 Bedroom      600.0   9.0  200.00    8
# 58                Murugeshpalya   6 Bedroom     1407.0   4.0  150.00    6
# 68          Devarachikkanahalli   8 Bedroom     1350.0   7.0   85.00    8
# 70                        other   3 Bedroom      500.0   3.0  100.00    3
# 78             Kaval Byrasandra       2 BHK      460.0   1.0   22.00    2
# 89                 Rajaji Nagar   6 Bedroom      710.0   6.0  160.00    6
# 119                 Hennur Road   2 Bedroom      276.0   3.0   23.00    2
# 129          Vishwapriya Layout   7 Bedroom      950.0   7.0  115.00    7
# 149                       other   6 Bedroom     1034.0   5.0  185.00    6
# 170                       other       6 BHK     1300.0   6.0   99.00    6
# 176          Kumaraswami Layout   5 Bedroom      600.0   3.0   85.00    5
# 193                       other   7 Bedroom     1800.0   7.0  250.00    7
# 258                       other   5 Bedroom     1200.0   5.0  170.00    5
# 282                       other   6 Bedroom     1450.0   6.0  250.00    6
# 299                  Giri Nagar   3 Bedroom      880.0   3.0  140.00    3
# 315                       other   5 Bedroom     1200.0   5.0  180.00    5
# 349                       other   3 Bedroom       11.0   3.0   74.00    3
# 397                       other       6 BHK      700.0   3.0  120.00    6
# 409               Sultan Palaya   2 Bedroom      550.0   1.0   62.00    2
# 413          Mahalakshmi Layout   6 Bedroom     1200.0   7.0  250.00    6
# 425                  Chandapura   6 Bedroom     1533.0   5.0   85.00    6
# 434          7th Phase JP Nagar   8 Bedroom     1200.0   8.0  250.00    8
# 480                       other       4 BHK     1150.0   4.0  260.00    4
# 481                 Basavangudi   4 Bedroom     1125.0   4.0  180.00    4
# 482               Kenchenahalli   5 Bedroom      500.0   3.0   65.00    5
# 483                       other   5 Bedroom     1200.0   5.0  190.00    5
# 491              Banjara Layout   3 Bedroom      600.0   3.0   58.00    3
# 513          8th Phase JP Nagar   4 Bedroom      660.0   4.0   90.00    4
# 554                   Hosa Road   6 Bedroom     1300.0   6.0  145.00    6
# 614             Margondanahalli   5 Bedroom      940.0   4.0  150.00    5
# 677                     Hormavu   7 Bedroom     1200.0   7.0  150.00    7
# 679                       other   5 Bedroom     1200.0   5.0  100.00    5
# 727                       other   5 Bedroom     1210.0   4.0  160.00    5
# 757                       other   5 Bedroom     1000.0   4.0  160.00    5
# 770                       other   9 Bedroom      600.0   9.0  190.00    9
# 783                       other   6 Bedroom      900.0   7.0   76.00    6
# 789                       other   6 Bedroom      600.0   4.0   65.00    6
# 794                       other   7 Bedroom     1875.0   2.0  300.00    7
# 807                  HBR Layout   4 Bedroom      675.0   3.0   59.00    4
# 833                       other       2 BHK      460.0   1.0   15.00    2
# 838                   TC Palaya   6 Bedroom     1000.0   6.0   69.00    6
# 857                 Vijayanagar   8 Bedroom      600.0   4.0   72.00    8
# 860       Raja Rajeshwari Nagar   6 Bedroom     1200.0   4.0  125.00    6
# 866                       other   5 Bedroom      900.0   3.0   80.00    5
# 938          5th Phase JP Nagar   9 Bedroom     1260.0  11.0  290.00    9
# 946                Kammanahalli   4 Bedroom     1080.0   3.0  155.00    4
# 956                Marathahalli   4 Bedroom      700.0   4.0   72.00    4
# 961                   Kothannur   3 Bedroom      600.0   4.0   95.00    3
# 976                 Uttarahalli   6 Bedroom     1200.0   4.0  225.00    6
# 992                Rajaji Nagar   4 Bedroom      315.0   4.0   90.00    4
# 1010                      other   4 Bedroom      600.0   3.0   65.00    4
# 1020                      other       1 BHK       15.0   1.0   30.00    1
# 1024         1st Phase JP Nagar   8 Bedroom     1200.0   7.0  240.00    8
# 1033                 Nagasandra   6 Bedroom     1500.0   5.0  130.00    6
# 1048                      other   9 Bedroom      900.0  10.0  170.00    9
# 1062                      other   4 Bedroom      915.0   4.0   54.90    4
# 1066               Yeshwanthpur   5 Bedroom      850.0   4.0   90.00    5
# 1103         5th Phase JP Nagar   9 Bedroom      812.0   6.0  165.00    9
# 1105                      Hoodi   8 Bedroom     1120.0   8.0  145.00    8
# 1108                    Kengeri   7 Bedroom     1200.0   6.0  140.00    7
# 1122                      other   5 Bedroom       24.0   2.0  150.00    5
# 1141                 R.T. Nagar   6 Bedroom     1200.0   7.0  165.00    6
# 1162        1st Block Jayanagar       6 BHK     1200.0   6.0  125.00    6
# 1220         Kumaraswami Layout   7 Bedroom      800.0   7.0  105.00    7
# 1222                     Ulsoor   9 Bedroom     2300.0   8.0  210.00    9
# 1233                      other   4 Bedroom      600.0   5.0   60.00    4
# 1239            Electronic City       2 BHK      550.0   1.0   16.00    2
# 1269       5th Block Hbr Layout   6 Bedroom     1200.0   6.0  250.00    6
# 1314               Malleshwaram   8 Bedroom      840.0   7.0  195.00    8
# 1364                      other   6 Bedroom     1200.0   6.0  180.00    6
# 1371               Marathahalli   5 Bedroom     1350.0   4.0  135.00    5
# 1379                      other   8 Bedroom     1200.0   7.0  235.00    8
# 1388     Kengeri Satellite Town   3 Bedroom      850.0   3.0   95.00    3
# 1419                      other   3 Bedroom      750.0   2.0   75.00    3
# 1448        Sector 7 HSR Layout   5 Bedroom      900.0   4.0   90.00    5
# 1481               Bannerghatta   4 Bedroom      810.0   4.0   50.00    4
# 1490               Malleshwaram   9 Bedroom      750.0   8.0  150.00    9
# 1492         9th Phase JP Nagar   7 Bedroom     1200.0   6.0  195.00    7
# 1519                      other   3 Bedroom      600.0   3.0   75.00    3
# 1567                Uttarahalli   5 Bedroom      400.0   5.0  200.00    5
# 1575                     Kogilu   7 Bedroom      925.0   7.0   88.00    7
# 1593                   JP Nagar   9 Bedroom     2550.0   9.0  360.00    9
# 1622                  Gubbalala   3 Bedroom      600.0   3.0   75.00    3
# 1624           Kereguddadahalli   6 Bedroom      600.0   4.0   60.00    6
# 1649                      other   4 Bedroom      817.0   2.0  120.00    4
# 1672                      other   6 Bedroom     1200.0   4.0  135.00    6
# 1685                   Kadugodi       5 BHK     1100.0   5.0  135.00    5
# 1718                      other      27 BHK     8000.0  27.0  230.00   27
# 1735                      other  10 Bedroom      750.0  10.0   90.00   10
# 1758                      other   8 Bedroom     1320.0   6.0  200.00    8
# 1768                      other  11 Bedroom     1200.0  11.0  170.00   11
# 1769                      other   6 Bedroom      727.0   6.0   66.00    6
# 1792         Yelahanka New Town       2 BHK      550.0   2.0   26.00    2
# 1795                      other  10 Bedroom     1660.0  10.0  475.00   10
# 1802                      other   4 Bedroom      712.0   2.0   67.50    4
# 1820       2nd Stage Nagarbhavi   5 Bedroom     1200.0   4.0  285.00    5
# 1825              Shivaji Nagar   7 Bedroom     1400.0   6.0  200.00    7
# 1830                  Hosa Road   3 Bedroom      675.0   3.0   72.50    3
# 1832               Banashankari   3 Bedroom      600.0   3.0  100.00    3
# 1860                      other   5 Bedroom     1350.0   4.0  130.00    5
# 1863                      other   3 Bedroom      600.0   2.0   60.00    3
# 1875               Yeshwanthpur   3 Bedroom      682.0   2.0  130.00    3
# 1887                      other       7 BHK      600.0   7.0  106.00    7
# 1937                      other   9 Bedroom     1200.0   9.0  120.00    9
# 1939                  Kothannur   6 Bedroom      930.0   6.0  135.00    6
# 1941         6th Phase JP Nagar   3 Bedroom      600.0   2.0  100.00    3
# 1953                   KR Puram   8 Bedroom     1200.0  12.0  110.00    8
# 1979                      other   8 Bedroom      990.0  12.0  120.00    8
# 1980             Jalahalli East   3 Bedroom      800.0   2.0   80.00    3
# 1984                 Chamrajpet   4 Bedroom     1080.0   4.0  250.00    4
# 2021               Yeshwanthpur   2 Bedroom      585.0   1.0   70.00    2
# 2040            Electronic City       2 BHK      550.0   1.0   15.00    2
# 2069                      other   2 Bedroom      500.0   2.0   70.00    2
# 2071                      other   2 Bedroom      432.0   2.0   40.00    2
# 2086              Chikkabanavar   5 Bedroom     1200.0   4.0   70.00    5
# 2126   Electronic City Phase II       2 BHK      545.0   1.0   27.00    2
# 2153                      other       4 BHK      800.0   4.0   80.00    4
# 2162                  Gottigere   8 Bedroom     1200.0   8.0   90.00    8
# 2168                      other   3 Bedroom      720.0   3.0   65.00    3
# 2177                      other   8 Bedroom     1200.0   8.0  190.00    8
# 2179                 Nagarbhavi   6 Bedroom     1200.0   5.0  240.00    6
# 2181                   Kothanur   4 Bedroom     1140.0   4.0   90.00    4
# 2184                      other   8 Bedroom     1500.0  10.0  165.00    8
# 2213                      other   5 Bedroom     1200.0   6.0  137.00    5
# 2322           Kaval Byrasandra   4 Bedroom      750.0   4.0  110.00    4
# 2328                      other   4 Bedroom      600.0   4.0   40.00    4
# 2353                      other   5 Bedroom     1200.0   4.0  100.00    5
# 2380                 Nagarbhavi   4 Bedroom      600.0   2.0  100.00    4
# 2391                      other   4 Bedroom      800.0   4.0  120.00    4
# 2401                 Nagarbhavi   3 Bedroom      600.0   2.0   80.00    3
# 2449                      other   3 Bedroom      600.0   2.0  110.00    3
# 2457                      other   5 Bedroom     1440.0   5.0  110.00    5
# 2459                 Rayasandra   7 Bedroom      700.0   6.0   85.00    7
# 2464                Vijayanagar   6 Bedroom     1230.0   4.0  210.00    6
# 2468       Vishveshwarya Layout   4 Bedroom      600.0   4.0   95.00    4
# 2486                Bhoganhalli        1 RK      296.0   1.0   22.89    1
# 2487                      other   5 Bedroom     1200.0   4.0   85.00    5
# 2495     Kengeri Satellite Town   3 Bedroom      600.0   4.0   72.00    3
# 2518              Hosakerehalli   4 Bedroom      800.0   4.0  120.00    4
# 2552           Ramamurthy Nagar   7 Bedroom     1500.0   9.0  250.00    7
# 2596             Vidyaranyapura   4 Bedroom      900.0   4.0  175.00    4
# 2634               Battarahalli   3 Bedroom      800.0   2.0   75.00    3
# 2635                 Nagarbhavi   3 Bedroom      600.0   3.0  100.00    3
# 2654                      other   4 Bedroom      450.0   3.0   53.00    4
# 2662               Sanjay nagar   4 Bedroom      750.0   2.0  110.00    4
# 2678                      other   3 Bedroom      600.0   2.0   30.00    3
# 2752                      other   7 Bedroom      600.0   7.0  108.00    7
# 2758                   KR Puram   4 Bedroom      600.0   5.0   75.00    4
# 2763                 Begur Road   3 Bedroom      680.0   4.0   68.00    3
# 2778               Rachenahalli   5 Bedroom      600.0   5.0   50.00    5
# 2786                   Hulimavu   4 Bedroom      800.0   4.0  110.00    4
# 2794               Kalyan nagar   6 Bedroom      800.0   6.0   98.00    6
# 2796            Electronic City       3 BHK      880.0   2.0   18.00    3
# 2799             Sarjapur  Road   4 Bedroom     1152.0   4.0  230.00    4
# 2803               Babusapalaya   6 Bedroom      810.0   5.0   95.00    6
# 2815             Vidyaranyapura   9 Bedroom     1200.0   9.0  100.00    9
# 2843               Bommanahalli   3 Bedroom      680.0   4.0   68.00    3
# 2857                 HBR Layout   9 Bedroom     1200.0   6.0  280.00    9
# 2864                Singasandra   4 Bedroom      525.0   5.0   56.00    4
# 2873             Vidyaranyapura   6 Bedroom     1060.0   6.0  110.00    6
# 2897                    Kengeri   4 Bedroom     1125.0   2.0   88.00    4
# 2900                 Nagarbhavi   3 Bedroom      600.0   3.0   83.00    3
# 2903         Kumaraswami Layout   3 Bedroom      600.0   3.0   98.00    3
# 2927                      other   7 Bedroom     1600.0   7.0  104.00    7
# 2929                      other   9 Bedroom     1500.0   6.0   80.00    9
# 2937                      other   7 Bedroom      780.0   7.0  150.00    7
# 2947                      other   5 Bedroom      600.0   3.0   86.00    5
# 3002                      other   5 Bedroom      800.0   5.0   98.00    5
# 3023              Akshaya Nagar   4 Bedroom     1080.0   4.0   75.00    4
# 3028                      other   5 Bedroom     1100.0   4.0  150.00    5
# 3039                      other   7 Bedroom      600.0   7.0   89.00    7
# 3054                  Kothannur   4 Bedroom      600.0   4.0   81.00    4
# 3083               Battarahalli   5 Bedroom     1350.0   3.0  110.00    5
# 3087                      other   5 Bedroom     1320.0   5.0  199.00    5
# 3092                      other   6 Bedroom     1222.0   5.0  250.00    6
# 3095                  TC Palaya   8 Bedroom     1200.0   7.0  110.00    8
# 3097                      other   5 Bedroom     1200.0   5.0  195.00    5
# 3105                      other   6 Bedroom     1500.0   7.0  220.00    6
# 3123       2nd Stage Nagarbhavi   5 Bedroom     1200.0   4.0  240.00    5
# 3157                      other   4 Bedroom      600.0   2.0   85.00    4
# 3191                      other   7 Bedroom     1000.0   7.0  160.00    7
# 3238   Electronic City Phase II       2 BHK      545.0   1.0   35.00    2
# 3246                   KR Puram   4 Bedroom     1000.0   4.0   75.00    4
# 3274               Vasanthapura       2 BHK      420.0   2.0   35.00    2
# 3275                      other   4 Bedroom      600.0   2.0   90.00    4
# 3297                Munnekollal   6 Bedroom     1200.0   4.0  110.00    6
# 3342                      other   3 Bedroom      440.0   3.0   50.00    3
# 3377                      other       5 BHK      950.0   5.0   90.00    5
# 3379                      other      19 BHK     2000.0  16.0  490.00   19
# 3388                     Jigani   5 Bedroom      600.0   5.0   50.00    5
# 3395                      other   6 Bedroom     1200.0   5.0  150.00    6
# 3397                      other   6 Bedroom     1200.0   7.0  170.00    6
# 3418         Kumaraswami Layout   5 Bedroom     1270.0   4.0  128.00    5
# 3437                      other   6 Bedroom      600.0   7.0   63.00    6
# 3450                  Yelahanka   5 Bedroom     1200.0   4.0  140.00    5
# 3469                      other   4 Bedroom      700.0   4.0  110.00    4
# 3506                      other   5 Bedroom     1200.0   5.0  185.00    5
# 3511                Uttarahalli   7 Bedroom     1200.0   7.0  225.00    7
# 3523                     Jigani  10 Bedroom     1200.0  10.0  105.00   10
# 3527     Banashankari Stage III   8 Bedroom     1200.0   7.0  350.00    8
# 3536                Thanisandra   5 Bedroom      750.0   4.0   62.00    5
# 3566               Bommenahalli   3 Bedroom      832.0   3.0   77.00    3
# 3575                BEML Layout   4 Bedroom     1196.0   3.0  150.00    4
# 3592         Vishwapriya Layout       4 BHK      600.0   3.0   73.00    4
# 3594             Subramanyapura   6 Bedroom     1200.0   6.0  170.00    6
# 3622               Malleshwaram   3 Bedroom      675.0   2.0  148.00    3
# 3685                      other   6 Bedroom      600.0   3.0   95.00    6
# 3692       5th Block Hbr Layout   5 Bedroom     1200.0   6.0  220.00    5
# 3732         Vishwapriya Layout   7 Bedroom      600.0   7.0   73.00    7
# 3787                      other   3 Bedroom      600.0   4.0  110.00    3
# 3794         7th Phase JP Nagar   6 Bedroom     1045.0   6.0  160.00    6
# 3805                 Seegehalli   5 Bedroom     1200.0   5.0  120.00    5
# 3815                 R.T. Nagar   9 Bedroom     1200.0  10.0  180.00    9
# 3822        Sector 2 HSR Layout   5 Bedroom     1200.0   4.0  160.00    5
# 3836                      other   4 Bedroom      600.0   5.0   85.00    4
# 3843                   KR Puram   7 Bedroom     1200.0   8.0  110.00    7
# 3853                      other  11 Bedroom     1200.0   6.0  150.00   11
# 3888            Electronic City       2 BHK      550.0   1.0   15.00    2
# 3915                      other   5 Bedroom     1250.0   5.0  300.00    5
# 3916                      other   7 Bedroom     1650.0   9.0  345.00    7
# 3942                 Begur Road   5 Bedroom      800.0   5.0   95.00    5
# 3945                      Hoodi   3 Bedroom      780.0   3.0   62.00    3
# 4011                      Hoodi   8 Bedroom     1120.0   8.0  150.00    8
# 4019             Yelachenahalli   5 Bedroom      897.0   2.0   85.00    5
# 4055               Marathahalli   4 Bedroom      800.0   4.0   86.00    4
# 4061                      other       7 BHK      600.0   4.0  100.00    7
# 4062           Hebbal Kempapura   4 Bedroom      800.0   5.0  155.00    4
# 4086             Sarjapur  Road   4 Bedroom        1.0   4.0  120.00    4
# 4089             Kanakpura Road   5 Bedroom     1080.0   6.0   65.00    5
# 4112                 R.T. Nagar   6 Bedroom     1500.0   6.0  240.00    6
# 4156                      other   4 Bedroom      971.0   2.0  135.00    4
# 4167         6th Phase JP Nagar   8 Bedroom     1650.0   6.0  135.00    8
# 4216             Vidyaranyapura   4 Bedroom      600.0   3.0   78.00    4
# 4248               Banashankari   9 Bedroom     1200.0   9.0  145.00    9
# 4254             Sahakara Nagar   5 Bedroom     1200.0   5.0  160.00    5
# 4270                      other   4 Bedroom     1150.0   3.0  110.00    4
# 4329           Ramamurthy Nagar       4 BHK      850.0   2.0   65.00    4
# 4345                   Abbigere   5 Bedroom     1200.0   4.0   98.00    5
# 4357               Rajaji Nagar   5 Bedroom     1200.0   3.0  260.00    5
# 4359                      other   6 Bedroom     1790.0   5.0  250.00    6
# 4369                 Nagasandra   7 Bedroom     1750.0   5.0  350.00    7
# 4379             Vidyaranyapura   8 Bedroom     1200.0   7.0  130.00    8
# 4395                      other   8 Bedroom     1200.0   8.0  275.00    8
# 4443              Akshaya Nagar   4 Bedroom      750.0   4.0   62.00    4
# 4446                      other   8 Bedroom      750.0   8.0  200.00    8
# 4450                      other   5 Bedroom     1200.0   4.0  120.00    5
# 4470                      other   6 Bedroom      875.0   3.0   98.00    6
# 4474                      other   4 Bedroom      910.0   4.0  140.00    4
# 4482                    Varthur   8 Bedroom      704.0   8.0   92.00    8
# 4492                      other   8 Bedroom     1200.0   7.0  220.00    8
# 4494                      other   2 Bedroom      580.0   2.0   95.00    2
# 4510                Munnekollal  10 Bedroom     1200.0   7.0  240.00   10
# 4517                      other   5 Bedroom      720.0   4.0   62.00    5
# 4540                  Jalahalli   3 Bedroom      600.0   3.0   60.00    3
# 4565                      other   9 Bedroom     1800.0   9.0  180.00    9
# 4576         Kumaraswami Layout   6 Bedroom      610.0   4.0   95.00    6
# 4589                      other   6 Bedroom      675.0   6.0  125.00    6
# 4595                      other   6 Bedroom      800.0   3.0  120.00    6
# 4601            Judicial Layout   6 Bedroom     1200.0   6.0  300.00    6
# 4666                  TC Palaya   5 Bedroom     1440.0   5.0  100.00    5
# 4683           Ramamurthy Nagar   9 Bedroom     2000.0   9.0  150.00    9
# 4684                Munnekollal  43 Bedroom     2400.0  40.0  660.00   43
# 4691                      other  10 Bedroom     2416.0  10.0  600.00   10
# 4697              Sarakki Nagar   6 Bedroom      880.0   6.0   75.00    6
# 4714                 Nagarbhavi   5 Bedroom     1200.0   4.0  240.00    5
# 4742         Basaveshwara Nagar   6 Bedroom      800.0   6.0  110.00    6
# 4744                      other   3 Bedroom      600.0   3.0   54.00    3
# 4812                      other   4 Bedroom     1150.0   4.0  110.00    4
# 4820                      other   5 Bedroom      958.0   3.0  210.00    5
# 4822                      other   7 Bedroom     1200.0   7.0  169.00    7
# 4828             Yelachenahalli   4 Bedroom      900.0   2.0  115.00    4
# 4836              Hosakerehalli   9 Bedroom     1380.0   9.0  150.00    9
# 4844                  Bellandur   7 Bedroom      700.0   8.0  100.00    7
# 4910               Sanjay nagar   5 Bedroom     1200.0   4.0  185.00    5
# 4912                      other   9 Bedroom      750.0   6.0  112.00    9
# 4916                      other      14 BHK     1250.0  15.0  125.00   14
# 4932               Banashankari   5 Bedroom      500.0   5.0   92.00    5
# 4936                 Anandapura   3 Bedroom      640.0   3.0   45.00    3
# 4957               Kammanahalli   3 Bedroom      540.0   3.0   60.00    3
# 4972                      other       7 BHK        5.0   7.0  115.00    7
# 5015         8th Phase JP Nagar   9 Bedroom     1200.0   8.0  225.00    9
# 5024                 HBR Layout   4 Bedroom      800.0   4.0  180.00    4
# 5033                      other   8 Bedroom     1224.0   4.0  200.00    8
# 5042                      other   6 Bedroom      825.0   6.0  400.00    6
# 5061                      other   4 Bedroom      750.0   4.0   85.00    4
# 5071                      other   8 Bedroom      600.0   8.0   70.00    8
# 5093            Margondanahalli   2 Bedroom      555.0   1.0   37.00    2
# 5112                      other   8 Bedroom     1200.0   8.0  220.00    8
# 5115        1st Block Jayanagar   7 Bedroom      930.0   4.0   85.00    7
# 5138               Marathahalli   6 Bedroom     1200.0   5.0  108.00    6
# 5151             Vidyaranyapura   7 Bedroom     1200.0   7.0  140.00    7
# 5166                      other   6 Bedroom      800.0   6.0   98.00    6
# 5171       2nd Stage Nagarbhavi   4 Bedroom      600.0   3.0   95.00    4
# 5180             Jalahalli East   4 Bedroom      720.0   4.0   48.00    4
# 5188                      other   6 Bedroom     1350.0   6.0  160.00    6
# 5197                      other   4 Bedroom      900.0   4.0   75.00    4
# 5204                      other   8 Bedroom     1200.0   7.0  100.00    8
# 5206                OMBR Layout   3 Bedroom      600.0   3.0  100.00    3
# 5251                      other   4 Bedroom     1100.0   5.0  121.00    4
# 5257                      other   4 Bedroom      900.0   4.0  175.00    4
# 5329             Banjara Layout   5 Bedroom     1200.0   5.0   96.00    5
# 5366                      other   3 Bedroom      660.0   2.0  100.00    3
# 5415                 BTM Layout   4 Bedroom      600.0   4.0  122.00    4
# 5441             Vidyaranyapura   3 Bedroom      462.0   3.0   38.00    3
# 5449               Indira Nagar   5 Bedroom     1000.0   5.0  180.00    5
# 5463                      other       6 BHK      800.0   6.0   75.00    6
# 5480                Vijayanagar   8 Bedroom     1470.0   6.0  300.00    8
# 5481       2nd Stage Nagarbhavi   3 Bedroom      600.0   4.0  100.00    3
# 5504                Vittasandra   7 Bedroom      621.0   7.0   64.00    7
# 5528                HRBR Layout   6 Bedroom     1200.0   6.0  250.00    6
# 5534                      other   6 Bedroom      840.0   8.0  120.00    6
# 5582               Bommanahalli   5 Bedroom     1200.0   7.0  125.00    5
# 5591             Vidyaranyapura   9 Bedroom     1200.0   9.0  175.00    9
# 5622     Kengeri Satellite Town       2 BHK      560.0   2.0   16.60    2
# 5635                      other   6 Bedroom      800.0   8.0  150.00    6
# 5666                      other   7 Bedroom     1500.0   6.0  210.00    7
# 5689                  Yelahanka   5 Bedroom     1200.0   5.0  162.00    5
# 5697                   Shampura   4 Bedroom      920.0   2.0   90.00    4
# 5732                      other   3 Bedroom      750.0   3.0  155.00    3
# 5740                      other   3 Bedroom      600.0   3.0   90.00    3
# 5760                Mallasandra   4 Bedroom      600.0   2.0   50.00    4
# 5770               Haralur Road   5 Bedroom     1200.0   5.0  255.00    5
# 5774                 R.T. Nagar   7 Bedroom      600.0   7.0   93.00    7
# 5777          Kodichikkanahalli   6 Bedroom     1600.0   4.0  200.00    6
# 5794                      other   9 Bedroom     1350.0   8.0  200.00    9
# 5805                      other   5 Bedroom     1200.0   5.0  300.00    5
# 5833                      other       6 BHK     1200.0   6.0  120.00    6
# 5840                  TC Palaya   8 Bedroom     1500.0   8.0  150.00    8
# 5841                      other   4 Bedroom      906.0   3.0   55.00    4
# 5843                      other   7 Bedroom     1200.0   7.0  169.00    7
# 5844                      other   6 Bedroom      850.0   7.0  100.00    6
# 5851                      other   5 Bedroom     1200.0   4.0  130.00    5
# 5858                   Shampura   6 Bedroom     1150.0   6.0   75.00    6
# 5868           Ramamurthy Nagar   3 Bedroom      800.0   4.0   88.00    3
# 5882                      other   3 Bedroom      800.0   2.0   80.00    3
# 5893                      other   4 Bedroom      600.0   5.0   75.00    4
# 5924                      other   3 Bedroom      600.0   2.0   85.00    3
# 5934                      other   5 Bedroom      875.0   5.0  120.00    5
# 5965                      other   6 Bedroom      600.0   4.0  105.00    6
# 5968                      other   5 Bedroom     1240.0   5.0  300.00    5
# 5970                Mysore Road   1 Bedroom       45.0   1.0   23.00    1
# 6012                    Kengeri   3 Bedroom      600.0   3.0   90.00    3
# 6017                   Hulimavu   5 Bedroom     1200.0   5.0  101.00    5
# 6028               Banashankari       6 BHK     1200.0   6.0  180.00    6
# 6052                      other   7 Bedroom      600.0   7.0  110.00    7
# 6061                      other   6 Bedroom      806.0   3.0  128.00    6
# 6068                      other   8 Bedroom      600.0   6.0   60.00    8
# 6073             Horamavu Agara   6 Bedroom     1000.0   5.0   98.00    6
# 6096      Banashankari Stage II   2 Bedroom      500.0   2.0   55.00    2
# 6140                     Marsur       2 BHK      497.0   1.0   17.00    2
# 6148                   Shampura       4 BHK      672.0   3.0   54.00    4
# 6149                      other       8 BHK      800.0   6.0  110.00    8
# 6168        1st Block Jayanagar   8 Bedroom      700.0   4.0  104.00    8
# 6169                HRBR Layout   6 Bedroom     1000.0   6.0  275.00    6
# 6179                      other   3 Bedroom      396.0   2.0   48.00    3
# 6184                      other   5 Bedroom      600.0   4.0   76.00    5
# 6194                Basavangudi   6 Bedroom     1754.0   6.0  650.00    6
# 6211                      other   5 Bedroom     1200.0   4.0  115.00    5
# 6214          Bannerghatta Road   6 Bedroom     1200.0   6.0  160.00    6
# 6230                    Kengeri   6 Bedroom     1500.0   6.0  150.00    6
# 6231                      other   5 Bedroom     1200.0   5.0   99.00    5
# 6248                      other   5 Bedroom     1280.0   3.0  250.00    5
# 6283                      other   5 Bedroom     1050.0   4.0   80.00    5
# 6295         Mahalakshmi Layout   5 Bedroom     1200.0   5.0  200.00    5
# 6297                      other   3 Bedroom      600.0   4.0   81.00    3
# 6309       Vishveshwarya Layout   7 Bedroom     1200.0   8.0  180.00    7
# 6319                  TC Palaya   4 Bedroom      600.0   4.0   65.00    4
# 6338           Ramamurthy Nagar   6 Bedroom     1200.0   4.0  110.00    6
# 6360             Vidyaranyapura   4 Bedroom      750.0   4.0   88.00    4
# 6364      Banashankari Stage II   4 Bedroom     1050.0   3.0  125.00    4
# 6408                      other   4 Bedroom      900.0   3.0   51.00    4
# 6451                      other  10 Bedroom     1200.0  10.0  190.00   10
# 6458                      other       4 BHK     1050.0   4.0   90.00    4
# 6478              Shivaji Nagar       2 BHK      550.0   1.0   27.00    2
# 6486         Basaveshwara Nagar   6 Bedroom      750.0   4.0  150.00    6
# 6505               Yeshwanthpur   9 Bedroom     2400.0   6.0  270.00    9
# 6507                      other   3 Bedroom      800.0   3.0  120.00    3
# 6532                Uttarahalli   6 Bedroom     1680.0   6.0  125.00    6
# 6533                Mysore Road  12 Bedroom     2232.0   6.0  300.00   12
# 6538                    Hoskote   9 Bedroom     1800.0  10.0  185.00    9
# 6593                      other   3 Bedroom      700.0   3.0  195.00    3
# 6606                      other   9 Bedroom     1200.0   7.0   95.00    9
# 6607                Kodigehalli       8 BHK     1150.0   9.0  170.00    8
# 6621                      other   7 Bedroom      600.0   6.0  138.00    7
# 6628                  Banaswadi   6 Bedroom     1000.0   4.0  150.00    6
# 6633                    Hoskote   5 Bedroom      900.0   5.0  110.00    5
# 6700               Kammanahalli   4 Bedroom      900.0   4.0  150.00    4
# 6706                   Kothanur   8 Bedroom     1020.0  10.0  155.00    8
# 6726                      other       2 BHK      596.0   2.0   22.00    2
# 6764                      other   6 Bedroom      850.0   6.0   78.00    6
# 6790       Vishveshwarya Layout   3 Bedroom      600.0   4.0   99.00    3
# 6813        Sector 2 HSR Layout   9 Bedroom      600.0   9.0   90.00    9
# 6818                 Giri Nagar   6 Bedroom      600.0   6.0  100.00    6
# 6830                      other   3 Bedroom      800.0   3.0   60.00    3
# 6843                      other   5 Bedroom     1000.0   5.0  140.00    5
# 6868                      other   8 Bedroom     1200.0   8.0  135.00    8
# 6899                      other   4 Bedroom      882.0   3.0   72.00    4
# 6904                      other   3 Bedroom      600.0   3.0   65.00    3
# 6918       2nd Stage Nagarbhavi   4 Bedroom      600.0   4.0  125.00    4
# 6937       5th Block Hbr Layout   9 Bedroom     2600.0  12.0  675.00    9
# 6951     Banashankari Stage III   5 Bedroom     1200.0   5.0  180.00    5
# 6969                Singasandra   6 Bedroom     1200.0   6.0  220.00    6
# 6985                      other   6 Bedroom     1200.0   4.0  115.00    6
# 7003                      other   7 Bedroom     1200.0   5.0   80.00    7
# 7027                      other   5 Bedroom      800.0   4.0   98.00    5
# 7042               Kammanahalli   3 Bedroom      600.0   2.0   50.00    3
# 7060                Munnekollal   9 Bedroom     1200.0   9.0  215.00    9
# 7083                      other   3 Bedroom      646.0   2.0   65.00    3
# 7087         Vishwapriya Layout   5 Bedroom      690.0   4.0   83.00    5
# 7090                 Chandapura       3 BHK      715.0   2.0   32.00    3
# 7093                      other   8 Bedroom     1350.0   8.0  185.00    8
# 7106         6th Phase JP Nagar   4 Bedroom      600.0   4.0  125.00    4
# 7120               Amruthahalli   4 Bedroom      600.0   4.0   60.00    4
# 7142                      other   4 Bedroom      600.0   3.0  100.00    4
# 7175             Vidyaranyapura   5 Bedroom     1200.0   5.0  139.00    5
# 7185                  Hosa Road   3 Bedroom      675.0   3.0   70.00    3
# 7199                     Tindlu   3 Bedroom      720.0   3.0   81.00    3
# 7250                      other   7 Bedroom     1280.0   5.0  150.00    7
# 7256                      other       9 BHK     2400.0   8.0  325.00    9
# 7289                      other   5 Bedroom     1008.0   4.0  180.00    5
# 7298                    Arekere   8 Bedroom     1200.0   8.0  225.00    8
# 7331                      other   8 Bedroom     1000.0   7.0  160.00    8
# 7349                      other   3 Bedroom      800.0   2.0   52.00    3
# 7360                      other       6 BHK      900.0   5.0  100.00    6
# 7374   Electronic City Phase II       3 BHK      875.0   2.0   40.00    3
# 7403                      other   4 Bedroom     1050.0   4.0   90.00    4
# 7455                 Giri Nagar   4 Bedroom     1120.0   4.0  175.00    4
# 7459           Ramamurthy Nagar   5 Bedroom     1350.0   5.0  120.00    5
# 7468               Rajaji Nagar   5 Bedroom      900.0   4.0  140.00    5
# 7476                      other       6 BHK     1034.0   6.0  101.00    6
# 7495             Subramanyapura   3 Bedroom      600.0   3.0   69.00    3
# 7528       Vishveshwarya Layout   4 Bedroom      600.0   4.0   85.00    4
# 7535                      other       4 BHK     1140.0   3.0  145.00    4
# 7537                      other   4 Bedroom     1140.0   3.0  225.00    4
# 7554                      other   6 Bedroom     1200.0   4.0  100.00    6
# 7556                      other   5 Bedroom     1200.0   6.0   86.00    5
# 7568                      other   4 Bedroom      600.0   4.0   87.00    4
# 7573                      Hoodi   4 Bedroom     1100.0   4.0  120.00    4
# 7576                      other   3 Bedroom      600.0   3.0   70.00    3
# 7581                      other   6 Bedroom     1050.0   4.0  155.00    6
# 7587             CV Raman Nagar   4 Bedroom     1100.0   4.0  220.00    4
# 7611             Yelachenahalli   4 Bedroom      900.0   2.0  115.00    4
# 7643                   KR Puram   8 Bedroom     1500.0   7.0  382.00    8
# 7648                      other   4 Bedroom      600.0   3.0   65.00    4
# 7655                      other   3 Bedroom      600.0   4.0  100.00    3
# 7692                      other   6 Bedroom      900.0   6.0  170.00    6
# 7693                   KR Puram   4 Bedroom      960.0   4.0   80.00    4
# 7704                      other   6 Bedroom     1200.0   4.0   90.00    6
# 7711                      other   7 Bedroom     1200.0   5.0  180.00    7
# 7731                      other   5 Bedroom     1200.0   3.0   95.00    5
# 7733                 Kudlu Gate   9 Bedroom     1150.0   9.0  140.00    9
# 7753                      other   4 Bedroom      750.0   2.0   42.00    4
# 7825            Electronic City       2 BHK      550.0   1.0   15.00    2
# 7828                     Kogilu   8 Bedroom     1200.0   6.0  105.00    8
# 7836                ISRO Layout   4 Bedroom      950.0   3.0  179.00    4
# 7841               Billekahalli   5 Bedroom     1180.0   5.0   98.50    5
# 7849                      other       4 BHK      750.0   6.0   75.00    4
# 7859           Ramamurthy Nagar   4 Bedroom      945.0   5.0  120.00    4
# 7877                 Nagarbhavi   3 Bedroom      800.0   3.0   95.00    3
# 7886         Basaveshwara Nagar   8 Bedroom     1230.0   6.0  250.00    8
# 7906                 Nagarbhavi   4 Bedroom      600.0   5.0   95.00    4
# 7910      Banashankari Stage VI   3 Bedroom      600.0   4.0   90.00    3
# 7926                      other       3 BHK      780.0   3.0   75.00    3
# 7945                     Ulsoor   5 Bedroom     1200.0   4.0  150.00    5
# 7993              HAL 2nd Stage   7 Bedroom     1000.0   7.0  250.00    7
# 7999                      other   5 Bedroom     1200.0   3.0  180.00    5
# 8005         Kumaraswami Layout   6 Bedroom      600.0   6.0  100.00    6
# 8006                      other   4 Bedroom      750.0   4.0   95.00    4
# 8008       2nd Stage Nagarbhavi   5 Bedroom     1200.0   4.0  240.00    5
# 8012           Ramamurthy Nagar   4 Bedroom      960.0   2.0  138.00    4
# 8021                      other   7 Bedroom     1200.0   6.0  115.00    7
# 8029              Bisuvanahalli       3 BHK      873.0   2.0   40.00    3
# 8035      Banashankari Stage VI   3 Bedroom      600.0   3.0   90.00    3
# 8071                      other   5 Bedroom     1000.0   4.0   90.00    5
# 8082             Sarjapur  Road   5 Bedroom     1200.0   4.0   95.00    5
# 8106                      other   8 Bedroom     1850.0  12.0  300.00    8
# 8107         Mahalakshmi Layout   4 Bedroom     1050.0   1.0   35.00    4
# 8126         9th Phase JP Nagar   5 Bedroom     1200.0   5.0  160.00    5
# 8128         Vishwapriya Layout   4 Bedroom      720.0   3.0   95.00    4
# 8130                      other   4 Bedroom      860.0   4.0  125.00    4
# 8146             Sarjapur  Road   5 Bedroom     1480.0   4.0  169.00    5
# 8154                      other   9 Bedroom     1200.0   8.0  270.00    9
# 8190                      other   8 Bedroom     1200.0   8.0  150.00    8
# 8201                ISRO Layout   6 Bedroom     1200.0   6.0  230.00    6
# 8288                      other   4 Bedroom      400.0   2.0   35.00    4
# 8314                      other   5 Bedroom      900.0   6.0   95.00    5
# 8369                 Nagasandra   4 Bedroom      600.0   4.0   80.00    4
# 8435                  Jalahalli   4 Bedroom     1000.0   4.0   90.00    4
# 8490                      other   5 Bedroom     1200.0   4.0  150.00    5
# 8494                      other   2 Bedroom      360.0   2.0   40.00    2
# 8517                      other   4 Bedroom      360.0   4.0   37.00    4
# 8563                      other   4 Bedroom     1050.0   3.0   85.00    4
# 8576                 HSR Layout   8 Bedroom      800.0   8.0  285.00    8
# 8627              Kenchenahalli   3 Bedroom      480.0   3.0   65.00    3
# 8633                      other   5 Bedroom     1200.0   5.0   90.00    5
# 8640                Vijayanagar   5 Bedroom      750.0   4.0   95.00    5
# 8655               Rajaji Nagar   2 Bedroom      432.0   2.0   65.00    2
# 8673             Sahakara Nagar   5 Bedroom     1000.0   5.0  130.00    5
# 8748         Mahalakshmi Layout   8 Bedroom     1135.0   4.0  190.00    8
# 8762                      other   4 Bedroom      600.0   4.0   77.00    4
# 8775   Electronic City Phase II       2 BHK      545.0   1.0   29.00    2
# 8787                     Marsur       2 BHK      497.0   1.0   25.00    2
# 8830                   Sarjapur       2 BHK      535.0   1.0   20.00    2
# 8847                 Anandapura   6 Bedroom     1380.0   7.0  130.00    6
# 8876               Marathahalli   7 Bedroom     1550.0   7.0  160.00    7
# 8883                      other   7 Bedroom     1200.0   7.0  139.00    7
# 8930                      other   6 Bedroom     1680.0   4.0  250.00    6
# 8957                    Laggere   8 Bedroom     1800.0   8.0  110.00    8
# 8966       Vishveshwarya Layout   6 Bedroom     1400.0   6.0  160.00    6
# 8986                  Jalahalli   8 Bedroom     1244.0   6.0  130.00    8
# 8987                      other   4 Bedroom      750.0   4.0  120.00    4
# 9014                      other   3 Bedroom      720.0   3.0   48.00    3
# 9035                  Kothannur   6 Bedroom      930.0   6.0  150.00    6
# 9040                     Marsur       3 BHK      720.0   2.0   32.00    3
# 9127       2nd Stage Nagarbhavi   5 Bedroom     1200.0   4.0  240.00    5
# 9170     Banashankari Stage III   4 Bedroom     1050.0   3.0  147.00    4
# 9173                      other   5 Bedroom     1200.0   5.0  260.00    5
# 9180   Electronics City Phase 1   6 Bedroom     1314.0   5.0  120.00    6
# 9186               Battarahalli   6 Bedroom     1200.0   6.0  100.00    6
# 9211            Judicial Layout       7 BHK     1200.0   7.0  199.00    7
# 9249                      other   6 Bedroom     1200.0   6.0  125.00    6
# 9252                      other       2 BHK      565.0   2.0   15.00    2
# 9275               Kammanahalli   6 Bedroom     1000.0   6.0  150.00    6
# 9342        1st Block Jayanagar   8 Bedroom     1700.0   3.0   50.00    8
# 9355                Mysore Road   4 Bedroom      540.0   4.0   85.00    4
# 9391                      other   3 Bedroom      600.0   2.0   85.00    3
# 9456         9th Phase JP Nagar   3 Bedroom      600.0   3.0   79.00    3
# 9472                      other   4 Bedroom      720.0   4.0   95.00    4
# 9511                Munnekollal  10 Bedroom     1200.0   8.0  230.00   10
# 9517                 HSR Layout   9 Bedroom     1200.0   9.0  350.00    9
# 9540                      other   7 Bedroom     1300.0   4.0   52.00    7
# 9551                      other   5 Bedroom      950.0   5.0   55.00    5
# 9577                 Chandapura   5 Bedroom     1200.0   3.0   79.00    5
# 9616                      other   4 Bedroom      612.0   3.0   47.00    4
# 9633                Uttarahalli   6 Bedroom     1080.0   5.0  160.00    6
# 9636         7th Phase JP Nagar   6 Bedroom      650.0   6.0   80.00    6
# 9640         8th Phase JP Nagar   6 Bedroom     1200.0   6.0  260.00    6
# 9652                      other   6 Bedroom     1508.0   5.0  240.00    6
# 9668                    Varthur       5 BHK     1000.0   4.0   65.00    5
# 9686            Electronic City   5 Bedroom      717.0   5.0   78.00    5
# 9689         9th Phase JP Nagar   3 Bedroom      600.0   3.0   85.00    3
# 9693                Kodigehalli   2 Bedroom      500.0   1.0   55.00    2
# 9718                  Yelahanka   7 Bedroom     1400.0   5.0  175.00    7
# 9747                     Marsur       2 BHK      497.0   1.0   20.00    2
# 9774                      other   3 Bedroom      500.0   2.0   75.00    3
# 9803         9th Phase JP Nagar   7 Bedroom      820.0   7.0  140.00    7
# 9828               Banashankari   4 Bedroom      675.0   4.0  140.00    4
# 9830       2nd Stage Nagarbhavi   5 Bedroom     1200.0   4.0  240.00    5
# 9842                 Dasanapura       2 BHK      545.0   2.0   22.34    2
# 9862         9th Phase JP Nagar   6 Bedroom      600.0   6.0   75.00    6
# 9869                      other   5 Bedroom      750.0   3.0   95.00    5
# 9887       2nd Stage Nagarbhavi   5 Bedroom     1200.0   5.0  290.00    5
# 9889                 Begur Road   5 Bedroom     1100.0   5.0  165.00    5
# 9904                      other       5 BHK      600.0   6.0   72.00    5
# 9905                      other   4 Bedroom      600.0   4.0   60.00    4
# 9909                Uttarahalli   6 Bedroom     1200.0   6.0  330.00    6
# 9929                      other   5 Bedroom      800.0   5.0   95.00    5
# 9973                      other   6 Bedroom     1200.0   6.0  180.00    6
# 9990                      other   6 Bedroom     1200.0   9.0  122.00    6
# 9991              Sultan Palaya   6 Bedroom      890.0   5.0  160.00    6
# 9992                      other   3 Bedroom      857.0   3.0   95.00    3
# 10005                     other   6 Bedroom      600.0   5.0  130.00    6
# 10008                     other   8 Bedroom      600.0   4.0  175.00    8
# 10019                     other   5 Bedroom      570.0   5.0   80.00    5
# 10034               Kodigehalli       4 BHK      600.0   3.0   85.00    4
# 10068                Nagarbhavi   4 Bedroom      600.0   3.0   77.00    4
# 10085        Basaveshwara Nagar   4 Bedroom      700.0   4.0  125.00    4
# 10098              Yeshwanthpur       2 BHK      570.0   2.0   62.00    2
# 10101                     other   6 Bedroom     1200.0   5.0  280.00    6
# 10108                     other   6 Bedroom     1200.0   6.0  160.00    6
# 10109    Kengeri Satellite Town       5 BHK     1200.0   5.0   70.00    5
# 10111                     other   5 Bedroom     1035.0   5.0  170.00    5
# 10117                     other   4 Bedroom      740.0   2.0   24.50    4
# 10122    Kengeri Satellite Town   4 Bedroom      936.0   2.0   60.84    4
# 10133           Padmanabhanagar   3 Bedroom      610.0   2.0   75.00    3
# 10151     Banashankari Stage VI   4 Bedroom      600.0   3.0   97.00    4
# 10180                  KR Puram   6 Bedroom     1200.0   6.0  132.00    6
# 10197                     other   5 Bedroom      800.0   5.0   95.00    5
# 10198                 TC Palaya   5 Bedroom     1400.0   5.0   97.00    5
# 10202                     other       5 BHK     1200.0   4.0  115.00    5
# 10239               Konanakunte   9 Bedroom     1590.0   6.0  150.00    9
# 10276                    Marsur       3 BHK      715.0   2.0   29.00    3
# 10280        Kumaraswami Layout   6 Bedroom      510.0   4.0   70.00    6
# 10307                  Kothanur   8 Bedroom     1050.0   5.0   80.00    8
# 10313                Nagarbhavi   5 Bedroom     1200.0   4.0  240.00    5
# 10327                     other   4 Bedroom      702.0   4.0   65.00    4
# 10338            Banjara Layout   3 Bedroom      610.0   3.0   60.00    3
# 10386                     other       5 BHK      900.0   5.0  135.00    5
# 10461                     other   3 Bedroom      675.0   3.0   75.00    3
# 10475                     other   9 Bedroom     1200.0   9.0  230.00    9
# 10483      2nd Stage Nagarbhavi   5 Bedroom     1200.0   4.0  240.00    5
# 10499               Magadi Road   4 Bedroom      800.0   4.0   60.00    4
# 10509                     other       2 BHK      420.0   1.0   25.00    2
# 10524                     other   3 Bedroom      600.0   3.0  125.00    3
# 10526        Yelahanka New Town       1 BHK      284.0   1.0    8.00    1
# 10536                     other       6 BHK      499.0   5.0   89.00    6
# 10544                     other   4 Bedroom     1000.0   5.0  200.00    4
# 10590                     other   7 Bedroom     1900.0   3.0  162.00    7
# 10598     Banashankari Stage VI   8 Bedroom     1200.0   7.0  175.00    8
# 10649    Banashankari Stage III   9 Bedroom     1560.0   9.0  200.00    9
# 10674                NRI Layout   4 Bedroom      800.0   5.0   95.50    4
# 10695           Electronic City   9 Bedroom     1200.0  13.0  150.00    9
# 10698                     other   6 Bedroom     1350.0   4.0  203.00    6
# 10709                     other       2 BHK      550.0   1.0   20.00    2
# 10717     Banashankari Stage VI   4 Bedroom      600.0   5.0  105.00    4
# 10763                     other   5 Bedroom     1200.0   5.0  225.00    5
# 10786               Munnekollal   7 Bedroom     1200.0   5.0  185.00    7
# 10799                     other   4 Bedroom     1050.0   6.0   74.00    4
# 10810                     other   5 Bedroom     1200.0   5.0  138.00    5
# 10820                     other       3 BHK      840.0   2.0   35.00    3
# 10846                     other   6 Bedroom     1200.0   5.0  260.00    6
# 10886                Nagarbhavi   5 Bedroom     1200.0   4.0  240.00    5
# 10919          Ramamurthy Nagar   4 Bedroom      900.0   4.0   70.00    4
# 10981                 Hosa Road   5 Bedroom      900.0   5.0   55.00    5
# 11001                     other   4 Bedroom      875.0   4.0  150.00    4
# 11009      Vishveshwarya Layout   4 Bedroom      600.0   4.0   95.00    4
py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['price_per_sqft'] = df6['price_per_sqft'].astype(float)

# %%
df6['price_per_sqft'].describe()
# Out:
# count     12456.000000
# mean       6308.502826
# std        4168.127339
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('location'):
        m = np.mean(subdf.price_per_sqft)
        st = np.std(subdf.price_per_sqft)
        reduced_df = subdf[(subdf.price_per_sqft>(m-st)) & (subdf.price_per_sqft<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df7 = remove_pps_outliers(df6)
df7.shape
# Out:
# (10242, 7)

# %%
def plot_scatter_chart(df,location):
    bhk2 = df[(df.location==location) & (df.bhk==2)]
    bhk3 = df[(df.location==location) & (df.bhk==3)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.total_sqft,bhk2.price,color='blue',label='2 BHK', s=50)
    plt.scatter(bhk3.total_sqft,bhk3.price,marker='+', color='green',label='3 BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()
    
plot_scatter_chart(df7,"Rajaji Nagar")

# %%
plot_scatter_chart(df7,"Hebbal")

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
df8 = remove_bhk_outliers(df7)
# df8 = df7.copy()
df8.shape
# Out:
# (7317, 7)

# %%
plot_scatter_chart(df8,"Rajaji Nagar")

# %%
plot_scatter_chart(df8,"Hebbal")

# %%
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)
plt.hist(df8.price_per_sqft,rwidth=0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(df8.bath,rwidth=0.8)
plt.xlabel("Number of bathrooms")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df8[df8.bath>10]
# Out:
#             location    size total_sqft  bath  price  bhk  price_per_sqft
# 5277  Neeladri Nagar  10 BHK     4000.0  12.0  160.0   10     4000.000000
# 8483           other  10 BHK    12000.0  12.0  525.0   10     4375.000000
# 8572           other  16 BHK    10000.0  16.0  550.0   16     5500.000000
# 9306           other  11 BHK     6000.0  12.0  150.0   11     2500.000000
# 9637           other  13 BHK     5425.0  13.0  275.0   13     5069.124424

# %%
df8[df8.bath>df8.bhk+2]
# Out:
#            location       size total_sqft  bath   price  bhk  price_per_sqft
# 1626  Chikkabanavar  4 Bedroom     2460.0   7.0    80.0    4     3252.032520
# 5238     Nagasandra  4 Bedroom     7000.0   8.0   450.0    4     6428.571429
# 6711    Thanisandra      3 BHK     1806.0   6.0   116.0    3     6423.034330
# 8408          other      6 BHK    11338.0   9.0  1000.0    6     8819.897689

# %%
df9 = df8[df8.bath<df8.bhk+2]
df9.shape
# Out:
# (7239, 7)

# %%
df10 = df9.drop(['size','price_per_sqft'],axis='columns')
df10.head()
# Out:
#               location total_sqft  bath  price  bhk
# 0  1st Block Jayanagar     2850.0   4.0  428.0    4
# 1  1st Block Jayanagar     1630.0   3.0  194.0    3
# 2  1st Block Jayanagar     1875.0   2.0  235.0    3
# 3  1st Block Jayanagar     1200.0   2.0  130.0    3
# 4  1st Block Jayanagar     1235.0   2.0  148.0    2

# %%
dummies = pd.get_dummies(df10['location'])
dummies.head()
# Out:
#    1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                 True               False                      False
# 1                 True               False                      False
# 2                 True               False                      False
# 3                 True               False                      False
# 4                 True               False                      False
#
#    2nd Stage Nagarbhavi  5th Block Hbr Layout  5th Phase JP Nagar  \
# 0                 False                 False               False
# 1                 False                 False               False
# 2                 False                 False               False
# 3                 False                 False               False
# 4                 False                 False               False
#
#    6th Phase JP Nagar  7th Phase JP Nagar  8th Phase JP Nagar  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    9th Phase JP Nagar  ...  Vishveshwarya Layout  Vishwapriya Layout  \
# 0               False  ...                 False               False
# 1               False  ...                 False               False
# 2               False  ...                 False               False
# 3               False  ...                 False               False
# 4               False  ...                 False               False
#
#    Vittasandra  Whitefield  Yelachenahalli  Yelahanka  Yelahanka New Town  \
# 0        False       False           False      False               False
# 1        False       False           False      False               False
# 2        False       False           False      False               False
# 3        False       False           False      False               False
# 4        False       False           False      False               False
#
#    Yelenahalli  Yeshwanthpur  other
# 0        False         False  False
# 1        False         False  False
# 2        False         False  False
# 3        False         False  False
# 4        False         False  False
#
# [5 rows x 241 columns]

# %%
df11 = pd.concat([df10,dummies.drop("other",axis = 1)],axis = 1)
df11.head()
# Out:
#               location total_sqft  bath  price  bhk  1st Block Jayanagar  \
# 0  1st Block Jayanagar     2850.0   4.0  428.0    4                 True
# 1  1st Block Jayanagar     1630.0   3.0  194.0    3                 True
# 2  1st Block Jayanagar     1875.0   2.0  235.0    3                 True
# 3  1st Block Jayanagar     1200.0   2.0  130.0    3                 True
# 4  1st Block Jayanagar     1235.0   2.0  148.0    2                 True
#
#    1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 0               False                      False                 False
# 1               False                      False                 False
# 2               False                      False                 False
# 3               False                      False                 False
# 4               False                      False                 False
#
#    5th Block Hbr Layout  ...  Vijayanagar  Vishveshwarya Layout  \
# 0                 False  ...        False                 False
# 1                 False  ...        False                 False
# 2                 False  ...        False                 False
# 3                 False  ...        False                 False
# 4                 False  ...        False                 False
#
#    Vishwapriya Layout  Vittasandra  Whitefield  Yelachenahalli  Yelahanka  \
# 0               False        False       False           False      False
# 1               False        False       False           False      False
# 2               False        False       False           False      False
# 3               False        False       False           False      False
# 4               False        False       False           False      False
#
#    Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 0               False        False         False
# 1               False        False         False
# 2               False        False         False
# 3               False        False         False
# 4               False        False         False
#
# [5 rows x 245 columns]

# %%
df12 = df11.drop("location",axis=1)
df12.shape
# Out:
# (7239, 244)

# %%
X = df12.drop('price',axis = 1)
X.head(2)
# Out:
#   total_sqft  bath  bhk  1st Block Jayanagar  1st Phase JP Nagar  \
# 0     2850.0   4.0    4                 True               False
# 1     1630.0   3.0    3                 True               False
#
#    2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 0                      False                 False                 False
# 1                      False                 False                 False
#
#    5th Phase JP Nagar  6th Phase JP Nagar  ...  Vijayanagar  \
# 0               False               False  ...        False
# 1               False               False  ...        False
#
#    Vishveshwarya Layout  Vishwapriya Layout  Vittasandra  Whitefield  \
# 0                 False               False        False       False
# 1                 False               False        False       False
#
#    Yelachenahalli  Yelahanka  Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 0           False      False               False        False         False
# 1           False      False               False        False         False
#
# [2 rows x 243 columns]

# %%
y = df12['price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X,y)
lr.score(X_test,y_test)
# Out:
# 0.8712574323243515

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2,random_state=0)
cross_val_score(LinearRegression(),X,y,cv=cv).mean()
# Out:
# 0.8477957812447918

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'fit_intercept':[True,False],
                'copy_X':[True,False],
                'positive':[True,False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'squared_error', 'poisson', 'absolute_error', 'friedman_mse'}. Got 'mse' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.72950306 0.63761308]
#   warnings.warn(
#                model  best_score  \
# 0  linear_regression    0.856654
# 1              lasso    0.710533
# 2      decision_tree    0.729503
#
#                                          best_params
# 0  {'copy_X': True, 'fit_intercept': False, 'posi...
# 1                {'alpha': 1, 'selection': 'cyclic'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
def predict_price(location,sqft,bath,bhk):    
    loc_index = np.where(X.columns==location)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = sqft
    x[1] = bath
    x[2] = bhk
    if loc_index >= 0:
        x[loc_index] = 1

    return lr.predict([x])[0]

# %%
predict_price('1st Phase JP Nagar',1000, 2, 2)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 85.86534147391554

# %%
predict_price('1st Phase JP Nagar',1000, 3, 3)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 87.8679575424814

# %%
predict_price('Indira Nagar',1000, 2, 2)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 179.64845398510826

# %%
predict_price('Indira Nagar',1000, 3, 3)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 181.65107005367415

# %%
predict_price('Indira Nagar',1000, 2, 2)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 179.64845398510826

# %%
import pickle
with open('banglore_home_prices_model.pickle','wb') as f:
    pickle.dump(lr,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
